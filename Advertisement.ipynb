# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\sai\\Desktop\\jupyter_notebook_practise\\CSV-datasets\\Regression\\Advertising.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
s = df[['TV', 'radio', 'newspaper', 'sales']]

# %%
df = pd.DataFrame(s)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sns.distplot(df['sales']);
fig = plt.figure()

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
plt.scatter(df['TV'], df['sales'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = df[['TV', 'radio', 'newspaper']]
y = df['sales']

X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.2 , random_state = 5);

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([ 0.04688034,  0.1824328 , -0.00164674])

# %%
reg.intercept_
# Out:
# 2.931280343575775

# %%
reg.predict([[200,20,52]])
# Out:
# array([15.87037402])

# %%
y_pred = reg.predict(X_test)

# %%
print(y_pred)
# Out:
# [ 6.72296139 13.75631244 12.04517877  9.69967488 15.5690964  10.05604087
#  13.84462636 11.57199727 19.50132767 10.63532913 18.86878088  7.66094904
#  14.95238223 16.44076381 21.16915592 20.34689481 17.4717922  20.44501887
#   6.6345129  11.59504468 10.73339912 14.9550131  20.47462735 14.4053483
#  19.82336217 21.23329569 13.95616746 23.25585899  8.33169334 20.72918361
#  15.86252542 15.18601062 21.74577286 18.34562985 12.80653699  9.38349318
#   5.37438571 12.02365628 19.26275296  8.12044348]

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)

# %%
print(score)
# Out:
# 0.8984204533332627

# %%
print(score)
# Out:
# 0.8984204533332627

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sns.pairplot(df, hue = 'sales', size = 3)
# Out:
# C:\Users\sai\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\sai\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\sai\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\sai\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\sai\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
plt.scatter(df['TV'], df['sales'], color = "red")
plt.plot(df.iloc[:40, 0], df['sales'], color = "green")
plt.title("Advertisement (Training set)")
plt.xlabel("objects(TV, Radio, Newspaper)")
plt.ylabel("Sale")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1525cedc575d> in <module>
#       1 plt.scatter(df['TV'], df['sales'], color = "red")
# ----> 2 plt.plot(df.iloc[:40, 0], df['sales'], color = "green")
#       3 plt.title("Advertisement (Training set)")
#       4 plt.xlabel("objects(TV, Radio, Newspaper)")
#       5 plt.ylabel("Sale")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# ...

# %%
X = df[['TV', 'radio', 'newspaper']]
y = df['sales']

from sklearn.cluster import KMeans
#X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state = 0)
kmeans = KMeans(n_clusters = 4, random_state = 0)
kmeans.fit(X_test)
y_pred_KC = kmeans.predict(X_test)

from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, y_pred_KC)
print(score)
